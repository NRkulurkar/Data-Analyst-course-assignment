# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Data = {'Year': [1920,1930,1940,1950,1960,1970,1980,1990,2000, 2010, 2020],
       'Exchange Rate': [65, 69, 71, 64, 62, 59, 72, 71, 75, 78, 81]}

# %%
df=pd.DataFrame(Data, columns=['Year','Exchange Rate'])

# %%
df
# Out:
#     Year  Exchange Rate
# 0   1920             65
# 1   1930             69
# 2   1940             71
# 3   1950             64
# 4   1960             62
# 5   1970             59
# 6   1980             72
# 7   1990             71
# 8   2000             75
# 9   2010             78
# 10  2020             81

# %%
df.plot(x='Year',y='Exchange Rate', kind='bar')
plt.show()

# %%
df.plot(x='Year',y='Exchange Rate', kind='scatter')
plt.show()

# %%
plt.scatter(df['Year'], df['Exchange Rate'])
plt.show()

# %%
x=np.array([1,2,3,4,4,5,6,7,8,9])
y=np.array([23,12,34,23,89,90,3,45,6,15])
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(df.Year,df['Exchange Rate'])
plt.show()

# %%
Data={'Task':[100,500,300]}
df=pd.DataFrame(Data,columns=['Task'], index=['Pending','Ongoing','Completed'])

# %%
df.plot.pie(y='Task',figsize=(5,5))
plt.show()

# %%
df
# Out:
#            Task
# Pending     100
# Ongoing     500
# Completed   300

# %%
churn_df=pd.read_csv('Churn_Modelling.csv')

# %%
churn_df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
churn_df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
churn_df.Geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
churn_df.Geography.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
churn_df.Geography.value_counts().plot(kind='barh')
plt.show()

# %%
churn_df['Exited'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.bar(churn_df['Geography'],churn_df['EstimatedSalary'].mean(), color='cyan', edgecolor='orange')
plt.title('Geography vs EstimatedSalary')
plt.show()

# %%
plt.bar(churn_df['Geography'],churn_df['EstimatedSalary'].max(),color='cyan',edgecolor='orange')
plt.title('Geography vs Estimated Salary',fontdict={"fontsize":20,"color":"Green"})
plt.show()

# %%
plt.bar(churn_df['Gender'],churn_df['Age'].max(),color='cyan',edgecolor='orange')
plt.title('Male vs Female', fontdict={"fontsize":20, "color":'Green'})
plt.show()

# %%
plt.scatter(churn_df['Age'],churn_df['Tenure'])
plt.title('Scatter Plot')
plt.xlabel('This is X axis')
plt.ylabel('This is Y axis')
plt.show()

# %%
plt.hist(churn_df['Tenure'],bins=30)
plt.xlabel('Tenure')
plt.ylabel('Probability')
plt.show()

# %%
labels_ex='Javascript','Java','Python','R'
sizes=[15,30,45,10]
explode_labels=(0,0.5,0,0)
fig1, ax1=plt.subplots()
fig2, ax2=plt.subplots()
ax1.pie(sizes, explode=explode_labels,labels=labels_ex,shadow=True,startangle=90)
ax1.axis('equal')
ax2.pie(sizes, explode=explode_labels,labels=labels_ex,shadow=True,startangle=90)
ax2.axis('equal')
plt.show()

# %%
churn_df['Tenure'].plot.box()
plt.show()

# %%
churn_df['Tenure'].describe()
# Out:
# count    10000.000000
# mean         5.012800
# std          2.892174
# min          0.000000
# 25%          3.000000
# 50%          5.000000
# 75%          7.000000
# max         10.000000
# Name: Tenure, dtype: float64
